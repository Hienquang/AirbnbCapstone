# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the Data

# %%
listings = pd.read_csv('../listings_cleaned.csv')

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9277 entries, 0 to 9276
# Data columns (total 67 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            9277 non-null   int64
#  1   listing_url                                   9277 non-null   object
#  2   name                                          9277 non-null   object
#  3   description                                   9116 non-null   object
#  4   neighborhood_overview                         6648 non-null   object
#  5   picture_url                                   9277 non-null   object
#  6   host_id                                       9277 non-null   int64
#  7   host_url                                      9277 non-null   object
#  8   host_name                                     9274 non-null   object
#  9   host_since                                    9274 non-null   object
#  10  host_location                                 9260 non-null   object
#  11  host_about                                    6489 non-null   object
#  12  host_response_time                            8146 non-null   object
#  13  host_response_rate                            8146 non-null   object
#  14  host_acceptance_rate                          8657 non-null   object
#  15  host_is_superhost                             9274 non-null   object
#  16  host_thumbnail_url                            9274 non-null   object
#  17  host_picture_url                              9274 non-null   object
#  18  host_neighbourhood                            8323 non-null   object
#  19  host_listings_count                           9274 non-null   float64
#  20  host_total_listings_count                     9274 non-null   float64
#  21  host_verifications                            9277 non-null   object
#  22  host_has_profile_pic                          9274 non-null   object
#  23  host_identity_verified                        9274 non-null   object
#  24  neighbourhood_cleansed                        9277 non-null   object
#  25  latitude                                      9277 non-null   float64
#  26  longitude                                     9277 non-null   float64
#  27  property_type                                 9277 non-null   object
#  28  room_type                                     9277 non-null   object
#  29  accommodates                                  9277 non-null   int64
#  30  bathrooms_text                                9271 non-null   object
#  31  bedrooms                                      8292 non-null   float64
#  32  beds                                          9238 non-null   float64
#  33  amenities                                     9277 non-null   object
#  34  price                                         9277 non-null   float64
#  35  minimum_nights                                9277 non-null   int64
#  36  maximum_nights                                9277 non-null   int64
#  37  minimum_minimum_nights                        9277 non-null   float64
#  38  maximum_minimum_nights                        9277 non-null   float64
#  39  minimum_maximum_nights                        9277 non-null   float64
#  40  maximum_maximum_nights                        9277 non-null   float64
#  41  minimum_nights_avg_ntm                        9277 non-null   float64
#  42  maximum_nights_avg_ntm                        9277 non-null   float64
#  43  has_availability                              9277 non-null   object
#  44  availability_30                               9277 non-null   int64
#  45  availability_60                               9277 non-null   int64
#  46  availability_90                               9277 non-null   int64
#  47  availability_365                              9277 non-null   int64
#  48  calendar_last_scraped                         9277 non-null   object
#  49  number_of_reviews                             9277 non-null   int64
#  50  number_of_reviews_ltm                         9277 non-null   int64
#  51  number_of_reviews_l30d                        9277 non-null   int64
#  52  first_review                                  7858 non-null   object
#  53  last_review                                   7858 non-null   object
#  54  review_scores_rating                          7815 non-null   float64
#  55  review_scores_accuracy                        7770 non-null   float64
#  56  review_scores_cleanliness                     7771 non-null   float64
#  57  review_scores_checkin                         7767 non-null   float64
#  58  review_scores_communication                   7770 non-null   float64
#  59  review_scores_location                        7767 non-null   float64
#  60  review_scores_value                           7767 non-null   float64
#  61  instant_bookable                              9277 non-null   object
#  62  calculated_host_listings_count                9277 non-null   int64
#  63  calculated_host_listings_count_entire_homes   9277 non-null   int64
#  64  calculated_host_listings_count_private_rooms  9277 non-null   int64
#  65  calculated_host_listings_count_shared_rooms   9277 non-null   int64
#  66  reviews_per_month                             7858 non-null   float64
# dtypes: float64(21), int64(16), object(30)
# memory usage: 4.7+ MB

# %%
listings.head()
# Out:
#       id                         listing_url  \
# 0   5570   https://www.airbnb.com/rooms/5570
# 1  29967  https://www.airbnb.com/rooms/29967
# 2  38245  https://www.airbnb.com/rooms/38245
# 3  54001  https://www.airbnb.com/rooms/54001
# 4  62274  https://www.airbnb.com/rooms/62274
#
#                                               name  \
# 0                    Ocean front condo on the sand
# 1                 Great home, 10 min walk to Beach
# 2                       Point Loma: Den downstairs
# 3  La Jolla 2 Bdr Cottage: 1 Qn; 2Twns, Blks 2 Ocn
# 4               charming, colorful, close to beach
#
#                                          description  \
# 0  Missionbeachretreat.   Great Ocean Front Condo...
# 1  This 2 bedroom, 2 full bathroom home offers al...
# 2  Stay in a 1928 Spanish Style home.  Den is dow...
# 3  Quiet, off the beaten path, this secluded  cot...
# 4  Modern, cozy, artsy, and european in a lush ga...
#
#                                neighborhood_overview  \
# 0  While some may compare San Diego’s Mission Bea...
# 1                                                NaN
# 2  This neighborhood is an expensive, high-end Po...
# 3  Tranquility, stately trees, meditative, zen-fu...
# 4  We are in walking distance to Starbucks, Trade...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/d3342744-140a...     8435
# 1  https://a0.muscache.com/pictures/76103867/c9b5...   129123
# 2  https://a0.muscache.com/pictures/f3073822-e493...   164137
# 3  https://a0.muscache.com/pictures/47035b04-633c...   252692
# 4  https://a0.muscache.com/pictures/84577734/93ca...   302986
#
#                                    host_url    host_name  host_since  ...  \
# 0    https://www.airbnb.com/users/show/8435  Jef Karchin  2009-02-23  ...
# 1  https://www.airbnb.com/users/show/129123      Michael  2010-05-21  ...
# 2  https://www.airbnb.com/users/show/164137      Melinda  2010-07-12  ...
# 3  https://www.airbnb.com/users/show/252692       Marsha  2010-10-04  ...
# 4  https://www.airbnb.com/users/show/302986       Isabel  2010-11-28  ...
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                   NaN                         NaN                    NaN
# 1                  10.0                        10.0                   10.0
# 2                  10.0                        10.0                    9.0
# 3                  10.0                        10.0                   10.0
# 4                  10.0                        10.0                   10.0
#
#   review_scores_value instant_bookable calculated_host_listings_count  \
# 0                 NaN                f                              3
# 1                10.0                f                              5
# 2                 9.0                f                              3
# 3                10.0                f                              2
# 4                10.0                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           3
# 1                                           5
# 2                                           0
# 3                                           1
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            3
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                           0                NaN
# 1                                           0               0.48
# 2                                           0               1.13
# 3                                           0               2.02
# 4                                           0               5.06
#
# [5 rows x 67 columns]

# %%
pd.set_option('max_rows', None)
print(listings.loc[0,:])
pd.reset_option('max_rows')
# Out:
# id                                                                                           5570
# listing_url                                                     https://www.airbnb.com/rooms/5570
# name                                                                Ocean front condo on the sand
# description                                     Missionbeachretreat.   Great Ocean Front Condo...
# neighborhood_overview                           While some may compare San Diego’s Mission Bea...
# picture_url                                     https://a0.muscache.com/pictures/d3342744-140a...
# host_id                                                                                      8435
# host_url                                                   https://www.airbnb.com/users/show/8435
# host_name                                                                             Jef Karchin
# host_since                                                                             2009-02-23
# host_location                                                San Diego, California, United States
# host_about                                      Real estate broker,  Jef  Karchin real estate ...
# host_response_time                                                             within a few hours
# host_response_rate                                                                           100%
# host_acceptance_rate                                                                         100%
# host_is_superhost                                                                               f
# host_thumbnail_url                              https://a0.muscache.com/im/users/8435/profile_...
# host_picture_url                                https://a0.muscache.com/im/users/8435/profile_...
# host_neighbourhood                                                                  Mission Beach
# host_listings_count                                                                             3
# host_total_listings_count                                                                       3
# host_verifications                                                      ['email', 'phone', 'kba']
# host_has_profile_pic                                                                            t
# host_identity_verified                                                                          t
# neighbourhood_cleansed                                                                Mission Bay
# latitude                                                                                  32.7843
# longitude                                                                                -117.253
# property_type                                                                  Entire condominium
# room_type                                                                         Entire home/apt
# accommodates                                                                                    6
# bathrooms_text                                                                             1 bath
# bedrooms                                                                                        2
# beds                                                                                            4
# amenities                                       ['Stove', 'Smoke alarm', 'Refrigerator', 'Kitc...
# price                                                                                        2050
# minimum_nights                                                                                  3
# maximum_nights                                                                                365
# minimum_minimum_nights                                                                          3
# maximum_minimum_nights                                                                          3
# minimum_maximum_nights                                                                        365
# maximum_maximum_nights                                                                        365
# minimum_nights_avg_ntm                                                                          3
# maximum_nights_avg_ntm                                                                        365
# has_availability                                                                                t
# availability_30                                                                                21
# availability_60                                                                                44
# availability_90                                                                                74
# availability_365                                                                              232
# calendar_last_scraped                                                                  2021-01-24
# number_of_reviews                                                                               0
# number_of_reviews_ltm                                                                           0
# number_of_reviews_l30d                                                                          0
# first_review                                                                                  NaN
# last_review                                                                                   NaN
# review_scores_rating                                                                          NaN
# review_scores_accuracy                                                                        NaN
# review_scores_cleanliness                                                                     NaN
# review_scores_checkin                                                                         NaN
# review_scores_communication                                                                   NaN
# review_scores_location                                                                        NaN
# review_scores_value                                                                           NaN
# instant_bookable                                                                                f
# calculated_host_listings_count                                                                  3
# calculated_host_listings_count_entire_homes                                                     3
# calculated_host_listings_count_private_rooms                                                    0
# calculated_host_listings_count_shared_rooms                                                     0
# reviews_per_month                                                                             NaN
# Name: 0, dtype: object

# %% [markdown]
# ## Explore the Data
